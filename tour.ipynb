# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %%
df_1=pd.read_excel('./data_tour/부산지역 관광시설분야 공공데이터(열린관광시설정보)_수정.xlsx')
df_1
# Out:
#                 업체명     카테고리명               필지고유번호    시도명  시군구명 읍면동명   리명  \
# 0             버블스포츠  레저/체육/공원  2644010300109389824  부산광역시   강서구  강동동  NaN
# 1             제일낚시터  레저/체육/공원  2644010300101929984  부산광역시   강서구  강동동  NaN
# 2     강동에이스배트민턴전용구장  레저/체육/공원  2644010300129249792  부산광역시   강서구  강동동  NaN
# 3            강서해수랜드  레저/체육/공원  2644010300116480000  부산광역시   강서구  강동동  NaN
# 4            강서해수온천  레저/체육/공원  2644010300116480000  부산광역시   강서구  강동동  NaN
# ...             ...       ...                  ...    ...   ...  ...  ...
# 1869    씨라이프부산아쿠아리움   문화관광/명소  2635010600114109952  부산광역시  해운대구   중동  NaN
# 1870         동선장대중탕  레저/체육/공원  2635010600113979904  부산광역시  해운대구   중동  NaN
# 1871         엘시티홍보관   문화관광/명소  2635010600111240192  부산광역시  해운대구   중동  NaN
# 1872        쉼에스테틱스파  레저/체육/공원  2635010600111229952  부산광역시  해운대구   중동  NaN
# 1873       도당에스테틱스파  레저/체육/공원  2635010600111229952  부산광역시  해운대구   중동  NaN
#
#            번지       법정동코드       행정동코드  ...  \
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   업체명        1874 non-null   object
#  1   카테고리명      1874 non-null   object
#  2   필지고유번호     1874 non-null   int64
#  3   시도명        1874 non-null   object
#  4   시군구명       1874 non-null   object
#  5   읍면동명       1874 non-null   object
#  6   리명         119 non-null    object
#  7   번지         1874 non-null   object
#  8   법정동코드      1874 non-null   int64
#  9   행정동코드      1874 non-null   int64
#  10  도로명코드      1674 non-null   float64
#  11  도로명        1692 non-null   object
#  12  도로명상세      1692 non-null   object
#  13  경도         1874 non-null   float64
#  14  위도         1874 non-null   float64
#  15  폐업여부       1874 non-null   object
#  16  전화번호       1275 non-null   object
#  17  홈페이지주소     1547 non-null   object
#  18  주차가능여부     1555 non-null   object
# ...

# %%
df_1['폐업여부']
# Out:
# 0       Y
# 1       N
# 2       N
# 3       Y
# 4       N
#        ..
# 1869    N
# 1870    Y
# 1871    Y
# 1872    Y
# 1873    N
# Name: 폐업여부, Length: 1874, dtype: object

# %%
df_1= df_1[df_1['폐업여부'] == 'N']

# %%
df_1=df_1.reset_index(drop=True)

# %%
busan_1=pd.read_excel('./data_tour/부산관광지200개.xls')

# %%
busan_2=pd.read_excel('./data_tour/부산관광지93개.xls')

# %%
busan_total = pd.concat([busan_1,busan_2])
busan_total
# Out:
#              명칭     우편번호  관리자 전화번호                                주소  \
# 0         서면1번가    47289  NaN  NaN       부산광역시 부산진구 신천대로62번길 61(부전동)
# 1       재난안전체험관    46207  NaN  NaN          부산광역시 금정구 체육공원로399번길 324
# 2       보광사(부산)    48702  NaN  NaN           부산광역시 동구 범상로1번길 35(범일동)
# 3       금강사(부산)    47700  NaN  NaN           부산광역시 동래구 우장춘로 211(온천동)
# 4       광안리해수욕장    48303  NaN  NaN          부산광역시 수영구 광안해변로 219(광안동)
# ..          ...      ...  ...  ...                               ...
# 88         혜원정사  47582.0  NaN  NaN         부산광역시 연제구 고분로68번길 47(연산동)
# 89        조방해수탕  47366.0  NaN  NaN   부산광역시 부산진구 자유평화로37번길 15-19(범천동)
# 90    스파랜드 센텀시티  48058.0  NaN  NaN           부산광역시 해운대구 센텀남대로 35(우동)
# 91  다대포 꿈의 낙조분수  49527.0  NaN  NaN                부산광역시 사하구 몰운대1길 14
# 92     내원정사(부산)  49200.0  NaN  NaN  부산광역시 서구 엄광산로40번길 121-22(서대신동3가)
#
#            위도          경도                                                 개요  \
# ...

# %%
busan_total.to_csv('./data_tour/부산관광지293개.csv',encoding='utf-8',index=False)

# %%
pd.read_csv('./data_tour/부산관광지293개.csv',encoding='utf-8')
# Out:
#               명칭     우편번호  관리자 전화번호                                주소  \
# 0          서면1번가    47289  NaN  NaN       부산광역시 부산진구 신천대로62번길 61(부전동)
# 1        재난안전체험관    46207  NaN  NaN          부산광역시 금정구 체육공원로399번길 324
# 2        보광사(부산)    48702  NaN  NaN           부산광역시 동구 범상로1번길 35(범일동)
# 3        금강사(부산)    47700  NaN  NaN           부산광역시 동래구 우장춘로 211(온천동)
# 4        광안리해수욕장    48303  NaN  NaN          부산광역시 수영구 광안해변로 219(광안동)
# ..           ...      ...  ...  ...                               ...
# 288         혜원정사  47582.0  NaN  NaN         부산광역시 연제구 고분로68번길 47(연산동)
# 289        조방해수탕  47366.0  NaN  NaN   부산광역시 부산진구 자유평화로37번길 15-19(범천동)
# 290    스파랜드 센텀시티  48058.0  NaN  NaN           부산광역시 해운대구 센텀남대로 35(우동)
# 291  다대포 꿈의 낙조분수  49527.0  NaN  NaN                부산광역시 사하구 몰운대1길 14
# 292     내원정사(부산)  49200.0  NaN  NaN  부산광역시 서구 엄광산로40번길 121-22(서대신동3가)
#
#             위도          경도                                                 개요  \
# ...

# %%
data = pd.read_excel('./부산관광지_문화시설97개.xls')

# %%
data_1=pd.read_excel('./부산관광지레포츠_50개.xls')

# %%
data_2=pd.concat([data,data_1])

# %%
data_3=pd.concat([data_2,busan_total])

# %%
data_3.to_csv('./data_tour/부산관광지440개.csv',encoding='utf-8',index=False)

# %%
data_4=pd.read_csv('./data_tour/부산관광지440개.csv',encoding='utf-8')

# %%
data_4[['명칭']].to_csv('./data_tour/관광지명칭.csv',encoding='utf-8',index=False)
