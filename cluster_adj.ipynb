# %%
import pandas as pd
from collections import Counter

# %%
cluster_0=pd.read_csv('./cluster_0_adj.csv',encoding='utf-8')
cluster_0
# Out:
#        keyword  cluster                                               same
# 0        서면1번가        0  알차다 싫다 사이좋다 사납다 인상깊다 낯설다 외롭다 하얗다 해맑다 드물다 덩그러다 ...
# 1      광안리해수욕장        0  틀림없다 알차다 싫다 사이좋다 인상깊다 낯설다 외롭다 하얗다 못지않다 벌겋다 따갑다...
# 2       송정해수욕장        0  틀림없다 알차다 흐드러지다 싫다 사이좋다 인상깊다 낯설다 외롭다 휑하다 하얗다 못지...
# 3      해운대해수욕장        0  틀림없다 알차다 흐드러지다 싫다 사이좋다 인상깊다 낯설다 외롭다 휑하다 하얗다 못지...
# 4       일광해수욕장        0  틀림없다 알차다 흐드러지다 싫다 인상깊다 두드러지다 낯설다 외롭다 하얗다 못지않다 ...
# ..         ...      ...                                                ...
# 111     비석문화마을        0  틀림없다 알차다 싫다 거침없다 인상깊다 낯설다 못지않다 해맑다 드물다 시리다 바르다...
# 112   닥밭골 벽화마을        0  틀림없다 알차다 흐드러지다 싫다 사이좋다 거침없다 사납다 점잖다 인상깊다 낯설다 외...
# 113        해광사        0  알차다 싫다 외롭다 지겨우다 드물다 끄떡없다 가깝다 거칠다 뜨거우다 힘차다 얕다 반...
# 114  부산 해운대도서관        0  알차다 흐드러지다 싫다 낯설다 하얗다 따갑다 드물다 섭하다 가깝다 캄캄하다 거칠다 ...
# 115   해운대리버크루즈        0  알차다 싫다 인상깊다 하얗다 못지않다 해맑다 섭하다 시리다 가깝다 거칠다 힘차다 춥...
#
# [116 rows x 3 columns]

# %%
count_0=Counter(cluster_0['same'].str.split(expand=True).stack())
print(count_0.most_common(100))
# Out:
# [('알차다', 116), ('싫다', 116), ('춥다', 116), ('적다', 116), ('즐겁다', 116), ('어렵다', 116), ('낮다', 116), ('아름답다', 116), ('귀엽다', 116), ('멋있다', 116), ('엄청나다', 116), ('빠르다', 116), ('덥다', 116), ('야무지다', 116), ('이쁘다', 116), ('가볍다', 116), ('맑다', 116), ('밝다', 116), ('멀다', 116), ('멋지다', 116), ('가깝다', 115), ('좁다', 115), ('싸다', 115), ('비싸다', 115), ('깊다', 115), ('재미있다', 115), ('새롭다', 115), ('급하다', 115), ('무섭다', 114), ('젊다', 114), ('수많다', 114), ('낫다', 114), ('붉다', 113), ('아깝다', 112), ('반갑다', 111), ('푸르다', 111), ('힘드다', 110), ('놀랍다', 110), ('시끄럽다', 109), ('어둡다', 109), ('짙다', 108), ('못지않다', 107), ('뜨겁다', 106), ('차갑다', 106), ('습하다', 106), ('안타깝다', 105), ('고르다', 105), ('곱다', 105), ('가파르다', 105), ('느리다', 105), ('하얗다', 104), ('예뿌다', 104), ('드넓다', 104), ('쎄다', 104), ('낯설다', 103), ('정신없다', 103), ('아쉬우다', 102), ('묘하다', 102), ('그립다', 102), ('어이없다', 102), ('파랗다', 101), ('흔하다', 101), ('무겁다', 101), ('얕다', 101), ('색다르다', 101), ('슬프다', 101), ('걸맞다', 100), ('알맞다', 100), ('낡다', 99), ('정겹다', 98), ('빡세다', 98), ('환하다', 97), 
# ...

# %%
cluster_1=pd.read_csv('./cluster_1_adj.csv',encoding='utf-8')
cluster_1['keyword'].to_clipboard()

# %%
count_1=Counter(cluster_1['same'].str.split(expand=True).stack())
print(count_1.most_common(100))
# Out:
# [('맑다', 108), ('멀다', 108), ('귀엽다', 108), ('싫다', 107), ('빠르다', 106), ('적다', 106), ('멋있다', 105), ('이쁘다', 105), ('알차다', 104), ('재미있다', 104), ('비싸다', 103), ('즐겁다', 103), ('어렵다', 102), ('밝다', 102), ('가볍다', 100), ('좁다', 100), ('덥다', 99), ('멋지다', 98), ('가깝다', 94), ('아름답다', 94), ('깊다', 94), ('무섭다', 93), ('급하다', 92), ('새롭다', 92), ('춥다', 91), ('엄청나다', 89), ('젊다', 84), ('야무지다', 83), ('싸다', 82), ('낮다', 82), ('수많다', 82), ('반갑다', 74), ('붉다', 71), ('뜨겁다', 60), ('아깝다', 54), ('낫다', 52), ('아쉬우다', 51), ('정신없다', 49), ('어둡다', 48), ('놀랍다', 45), ('쎄다', 44), ('힘드다', 42), ('고르다', 42), ('시끄럽다', 40), ('드넓다', 39), ('낯설다', 39), ('무겁다', 37), ('낡다', 37), ('습하다', 37), ('느리다', 36), ('짙다', 36), ('차갑다', 36), ('색다르다', 35), ('안타깝다', 34), ('얕다', 34), ('빡세다', 33), ('차다', 33), ('환하다', 32), ('가파르다', 32), ('알맞다', 32), ('어이없다', 32), ('하얗다', 32), ('못지않다', 30), ('푸르다', 30), ('인상깊다', 29), ('힘차다', 28), ('예뿌다', 28), ('파랗다', 27), ('정겹다', 27), ('흔하다', 27), ('활기차다', 27), ('가까우다', 25), ('묘하다', 25), ('어려우다', 24), ('거칠다', 24), ('더우다', 2
# ...

# %%
cluster_2=pd.read_csv('./cluster_2_adj.csv',encoding='utf-8')
cluster_2['keyword'].to_clipboard()

# %%
count_1=Counter(cluster_2['same'].str.split(expand=True).stack())
print(count_1.most_common(100))
# Out:
# [('맑다', 93), ('빠르다', 92), ('어렵다', 91), ('멋지다', 90), ('깊다', 89), ('아름답다', 87), ('멋있다', 86), ('싫다', 85), ('멀다', 84), ('이쁘다', 84), ('귀엽다', 82), ('가볍다', 81), ('재미있다', 81), ('즐겁다', 81), ('밝다', 80), ('좁다', 80), ('가깝다', 79), ('적다', 79), ('젊다', 74), ('덥다', 73), ('춥다', 72), ('새롭다', 71), ('알차다', 70), ('붉다', 70), ('무섭다', 67), ('수많다', 67), ('낮다', 67), ('엄청나다', 66), ('급하다', 58), ('반갑다', 57), ('비싸다', 55), ('야무지다', 49), ('싸다', 46), ('어둡다', 44), ('안타깝다', 39), ('얕다', 39), ('푸르다', 37), ('짙다', 36), ('아깝다', 35), ('못지않다', 33), ('드넓다', 33), ('놀랍다', 32), ('드물다', 32), ('뜨겁다', 31), ('낫다', 31), ('걸맞다', 29), ('낡다', 29), ('뜻깊다', 28), ('힘드다', 28), ('낯설다', 28), ('느리다', 27), ('가파르다', 27), ('곱다', 27), ('하얗다', 27), ('무겁다', 26), ('습하다', 25), ('시끄럽다', 25), ('힘차다', 25), ('슬프다', 24), ('뛰어나다', 24), ('노랗다', 24), ('고르다', 23), ('귀하다', 22), ('정겹다', 22), ('색다르다', 22), ('눈부시다', 22), ('빡세다', 22), ('환하다', 22), ('기쁘다', 22), ('어려우다', 22), ('쎄다', 21), ('묘하다', 21), ('차갑다', 21), ('파랗다', 20), ('그립다', 20), ('부끄럽다', 20), ('가까우다', 19), (
# ...
